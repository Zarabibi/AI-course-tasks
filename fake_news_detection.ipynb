# %% [markdown]
# <a href="https://colab.research.google.com/github/Zarabibi/AI-course-tasks/blob/main/fake_news_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/news.csv')

# %%
import numpy as np
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
data.shape
# Out:
# (44898, 5)

# %%
data.isna().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
data['content']= data['subject'].astype(str) + "" + data['title'].astype(str)

# %%
data
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 44893  'Fully committed' NATO backs new U.S. approach...
# 44894  LexisNexis withdrew two products from Chinese ...
# 44895  Minsk cultural hub becomes haven from authorities
# 44896  Vatican upbeat on possibility of Pope Francis ...
# 44897  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 0      Donald Trump just couldn t wish all Americans ...       News
# 1      House Intelligence Committee Chairman Devin Nu...       News
# 2      On Friday, it was revealed that former Milwauk...       News
# ...

# %%
data['content'][44893]
# Out:
# "worldnews'Fully committed' NATO backs new U.S. approach on Afghanistan"

# %%
#steming
ps = PorterStemmer()

def steming(content):
  stemmed_content = re.sub('[^a-zA-Z]',' ',content)
  stemmed_content = stemmed_content.lower()
  steming_content = stemmed_content.split()
  stemmed_content= [ps.stem(word) for word in steming_content if word not in stopwords.words('english')]
  steming_content = ' '.join(steming_content)
  return steming_content

# %%
data['content'] = data['content'].apply(steming)

# %%
from tkinter.constants import X
X = data['content'].values
y = data['label'].values

# %%
print(X)
# Out:
# ['news donald trump sends out embarrassing new year s eve message this is disturbing'
#  'news drunk bragging trump staffer started russian collusion investigation'
#  'news sheriff david clarke becomes an internet joke for threatening to poke people in the eye'
#  ... 'worldnewsminsk cultural hub becomes haven from authorities'
#  'worldnewsvatican upbeat on possibility of pope francis visiting russia'
#  'worldnewsindonesia to buy billion worth of russian jets']

# %%
np.vectorize = TfidfVectorizer()
np.vectorize.fit(X)
X = np.vectorize.transform(X)

# %%
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 562143 stored elements and shape (44898, 26148)>
#   Coords	Values
#   (0, 5280)	0.3770998405772875
#   (0, 5385)	0.2411698464171795
#   (0, 6219)	0.3647848762611261
#   (0, 6577)	0.408945754985573
#   (0, 9754)	0.1794996604899337
#   (0, 11487)	0.31164615798895173
#   (0, 12225)	0.2143295576303854
#   (0, 12234)	0.12105524779207467
#   (0, 14267)	0.220883403156068
#   (0, 20385)	0.3509881813767544
#   (0, 22494)	0.2203238245878271
#   (0, 22979)	0.11392573362694756
#   (0, 26027)	0.27548021531392447
#   (1, 2132)	0.4202146850094008
#   (1, 3389)	0.37191925421291205
#   (1, 5573)	0.4182046350386501
#   (1, 9689)	0.3093624577451282
#   (1, 12234)	0.1226742776980467
#   (1, 19887)	0.26810699542876926
#   (1, 21435)	0.39384609552780514
#   (1, 21493)	0.3989007231076389
#   (1, 22979)	0.11544941123007503
#   (2, 614)	0.21705403582910054
#   (2, 1546)	0.30469098691835134
#   (2, 3172)	0.32617317805719004
#   :	:
# ...

# %%
train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify=y, random_state=2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
train_y_pred = model.predict(X_train)
train_accuracy = accuracy_score(train_y_pred, y_train)
print(train_accuracy)
# Out:
# 0.9895317111197728

# %%
test_y_pred = model.predict(X_test)
train_accuracy = accuracy_score(test_y_pred, y_test)
print(train_accuracy)
# Out:
# 0.9810690423162584

# %%
# mpredition system
input_data = X_test[10]

prediction = model.predict(input_data)
if (prediction[0]==1):
  print('The news is Real')
else:
  print('The news is Fake')
print(prediction)
# Out:
# The news is Fake
# [0]

# %%
# mpredition system
input_data = X_test[100]

prediction = model.predict(input_data)
if (prediction[0]==1):
  print('The news is Real')
else:
  print('The news is Fake')
print(prediction)
# Out:
# The news is Real
# [1]
